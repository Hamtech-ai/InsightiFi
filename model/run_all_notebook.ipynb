# %% [markdown]
# # Import libraries

# %%
import datetime as datetime
from feature_extraction.indicator_features import *
from feature_extraction.daily_features import *  
import matplotlib.pyplot as plt
from model import *
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
import pytse_client as tse
from pytse_client.download import download_financial_indexes
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from zigzag_indicator.zigzag import peak_valley_pivots

# %% [markdown]
# # Import data

# %%
tse.download(
    symbols = ['فولاد'],
    adjust = True, 
    write_to_csv = True, 
    include_jdate = True
)
folad = tse.Ticker(
    symbol = 'فولاد',  
    adjust = True
)
foladHist = folad.history
foladClient = folad.client_types

foladHist = foladHist[foladHist.columns[:-1].insert(0, foladHist.columns[-1]).to_list()] # change location of jdate

print(f'Shape of Folad price history: {foladHist.shape}')
print(f'{foladHist.info()}')
foladHist.head()
# Out:
# Shape of Folad price history: (3503, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3503 entries, 0 to 3502
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   jdate      3503 non-null   object
#  1   date       3503 non-null   datetime64[ns]
#  2   open       3503 non-null   float64
#  3   high       3503 non-null   float64
#  4   low        3503 non-null   float64
#  5   adjClose   3503 non-null   float64
#  6   value      3503 non-null   int64
#  7   volume     3503 non-null   int64
#  8   count      3503 non-null   int64
#  9   yesterday  3503 non-null   float64
#  10  close      3503 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(1)
# memory usage: 301.2+ KB
# None
#         jdate       date  open  high   low  adjClose         value     volume  \
# 0  1385-12-20 2007-03-11  16.0  16.0  16.0      16.0  889437216900  468077431
# 1  1385-12-21 2007-03-12  16.0  16.0  16.0      16.0  193879458000  100041000
# 2  1385-12-22 2007-03-13  16.0  16.0  16.0      16.0  249241504527  126270939
# 3  1385-12-23 2007-03-14  16.0  16.0  16.0      16.0   51666379451   26705128
# 4  1385-12-26 2007-03-17  16.0  16.0  16.0      16.0   28239006789   14877283
#
#    count  yesterday  close
# 0   7736       16.0   16.0
# 1   9214       16.0   16.0
# 2   5862       16.0   16.0
# 3   1901       16.0   16.0
# 4   1514       16.0   16.0

# %%
print(f"Shape of Folad's client history: {foladClient.shape}")
print(f'{foladClient.info()}')
foladClient.head()
# Out:
# Shape of Folad's client history: (3118, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3118 entries, 0 to 3117
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         3118 non-null   object
#  1   individual_buy_count         3118 non-null   object
#  2   corporate_buy_count          3118 non-null   object
#  3   individual_sell_count        3118 non-null   object
#  4   corporate_sell_count         3118 non-null   object
#  5   individual_buy_vol           3118 non-null   object
#  6   corporate_buy_vol            3118 non-null   object
#  7   individual_sell_vol          3118 non-null   object
#  8   corporate_sell_vol           3118 non-null   object
#  9   individual_buy_value         3118 non-null   object
#  10  corporate_buy_value          3118 non-null   object
#  11  individual_sell_value        3118 non-null   object
#  12  corporate_sell_value         3118 non-null   object
#  13  individual_buy_mean_price    3116 non-null   float64
#  14  individual_sell_mean_price   3118 non-null   float64
#  15  corporate_buy_mean_price     3040 non-null   float64
#  16  corporate_sell_mean_price    3050 non-null   float64
#  17  individual_ownership_change  3118 non-null   float64
# dtypes: float64(5), object(13)
# memory usage: 438.6+ KB
# None
#        date individual_buy_count corporate_buy_count individual_sell_count  \
# 0  20230124                 1485                  24                  2172
# 1  20230123                 2160                  28                  2683
# 2  20230122                 2371                  27                  3004
# 3  20230121                 5111                  35                  3504
# 4  20230118                 2660                  20                  2782
#
#   corporate_sell_count individual_buy_vol corporate_buy_vol  \
# 0                   10           32122656          41228418
# 1                   12           54896003          81882782
# 2                   18           67263080          64461154
# 3                   12          122403688         135266347
# 4                   15           52611620          46955784
#
#   individual_sell_vol corporate_sell_vol individual_buy_value  \
# 0            59103119           14247955         199567219820
# 1           111038744           25740041         342675193170
# 2           114287335           17436899         416557065830
# 3           231760997           25909038         752232028600
# 4            76227143           23340261         336387474630
#
#   corporate_buy_value individual_sell_value corporate_sell_value  \
# 0        255950145680          367073806570          88443558930
# 1        509366706530          691775253520         160266646180
# 2        397880468000          706611141550         107826392280
# 3        830806974460         1424087339450         158951663610
# 4        300800254330          487629870600         149557858360
#
#    individual_buy_mean_price  individual_sell_mean_price  \
# 0                6212.662484                 6210.734946
# 1                6242.261266                 6230.034928
# 2                6192.952595                 6182.759809
# 3                6145.501340                 6144.637613
# 4                6393.786670                 6397.063453
#
#    corporate_buy_mean_price  corporate_sell_mean_price  \
# 0               6208.100094                6207.456363
# 1               6220.681492                6226.355513
# 2               6172.406842                6183.805520
# 3               6142.007919                6134.989019
# 4               6406.031988                6407.720049
#
#    individual_ownership_change
# 0                  -26980463.0
# 1                  -56142741.0
# 2                  -47024255.0
# 3                 -109357309.0
# 4                  -23615523.0

# %%
foladClient = foladClient.iloc[::-1]
foladClient.reset_index(
    drop = True,
    inplace = True
)
foladClient['date'] = foladClient['date'].apply(
    lambda x: datetime.datetime.strptime(x, '%Y%m%d')
)
foladClient.iloc[:, 1:] = foladClient.iloc[:, 1:].astype('float')

foladClient.head()
# Out:
#         date  individual_buy_count  corporate_buy_count  \
# 0 2008-11-26                  14.0                  2.0
# 1 2008-11-29                 116.0                175.0
# 2 2008-11-30                  10.0                  2.0
# 3 2008-12-01                   8.0                  1.0
# 4 2008-12-02                   7.0                  1.0
#
#    individual_sell_count  corporate_sell_count  individual_buy_vol  \
# 0                    4.0                   1.0            106338.0
# 1                    3.0                   2.0           4718258.0
# 2                    1.0                   1.0             87219.0
# 3                    5.0                   1.0            128666.0
# 4                    1.0                   0.0             18553.0
#
#    corporate_buy_vol  individual_sell_vol  corporate_sell_vol  \
# 0            20010.0             126338.0                10.0
# 1         33691903.0             121402.0          38288759.0
# 2            12791.0             100000.0                10.0
# 3               10.0             128666.0                10.0
# 4            10000.0              28553.0                 0.0
#
#    individual_buy_value  corporate_buy_value  individual_sell_value  \
# 0          2.489373e+08         4.684412e+07            295757258.0
# 1          1.498023e+10         1.077130e+11            284080680.0
# 2          2.040052e+08         2.991886e+07            233900000.0
# 3          3.008211e+08         2.409000e+04            300821108.0
# 4          4.335836e+07         2.337000e+07             66728361.0
#
#    corporate_sell_value  individual_buy_mean_price  \
# 0          2.412000e+04                2341.000000
# 1          1.224092e+11                3174.949168
# 2          2.410000e+04                2339.000000
# 3          2.409000e+04                2338.000000
# 4          0.000000e+00                2337.000000
#
#    individual_sell_mean_price  corporate_buy_mean_price  \
# 0                      2341.0               2341.035482
# 1                      2340.0               3196.999767
# 2                      2339.0               2339.055508
# 3                      2338.0               2409.000000
# 4                      2337.0               2337.000000
#
#    corporate_sell_mean_price  individual_ownership_change
# 0                2412.000000                     -20000.0
# 1                3196.999795                    4596856.0
# 2                2410.000000                     -12781.0
# 3                2409.000000                          0.0
# 4                        NaN                     -10000.0

# %%
marketIndex = download_financial_indexes(
    symbols = 'شاخص كل', 
    write_to_csv = True
)
marketIndex = marketIndex['شاخص كل']
marketIndex.rename(
    columns = {'value': 'TEDPIX'}, 
    inplace = True
)

print(f'Shape of TEDPIX: {marketIndex.shape}')
marketIndex.head()
# Out:
# Shape of TEDPIX: (3417, 2)
#    TEDPIX       date
# 0  9248.9 2008-12-04
# 1  9248.9 2008-12-05
# 2  9178.3 2008-12-06
# 3  9130.5 2008-12-07
# 4  9089.2 2008-12-08

# %%
foladHist = foladHist[foladHist.columns].merge(
    marketIndex, 
    how = 'left', 
    on = 'date'
)
foladHist.head()
# Out:
#         jdate       date  open  high   low  adjClose         value     volume  \
# 0  1385-12-20 2007-03-11  16.0  16.0  16.0      16.0  889437216900  468077431
# 1  1385-12-21 2007-03-12  16.0  16.0  16.0      16.0  193879458000  100041000
# 2  1385-12-22 2007-03-13  16.0  16.0  16.0      16.0  249241504527  126270939
# 3  1385-12-23 2007-03-14  16.0  16.0  16.0      16.0   51666379451   26705128
# 4  1385-12-26 2007-03-17  16.0  16.0  16.0      16.0   28239006789   14877283
#
#    count  yesterday  close  TEDPIX
# 0   7736       16.0   16.0     NaN
# 1   9214       16.0   16.0     NaN
# 2   5862       16.0   16.0     NaN
# 3   1901       16.0   16.0     NaN
# 4   1514       16.0   16.0     NaN

# %% [markdown]
# # Features

# %%
calCols = calender_features(foladHist)
candelCols = candlestick_feature(foladHist)
prpCols = prp_based(foladHist)
retCols = ret_based(foladHist)
shiftCols = shift_data(foladHist)
wghtCols = weight_feature(foladHist)

priceFeatures = pd.concat(
    [
        foladHist,
        calCols,
        candelCols,
        prpCols,
        retCols,
        shiftCols,
        wghtCols
    ], axis = 1
)

priceFeatures = priceFeatures.merge(
    indv_nonindv_features(foladClient),
    how = 'left',
    on = 'date'
)

print(f'Shape of price features: {priceFeatures.shape}')
priceFeatures.head()
# Out:
# Shape of price features: (3503, 121)
#         jdate       date  open  high   low  adjClose         value     volume  \
# 0  1385-12-20 2007-03-11  16.0  16.0  16.0      16.0  889437216900  468077431
# 1  1385-12-21 2007-03-12  16.0  16.0  16.0      16.0  193879458000  100041000
# 2  1385-12-22 2007-03-13  16.0  16.0  16.0      16.0  249241504527  126270939
# 3  1385-12-23 2007-03-14  16.0  16.0  16.0      16.0   51666379451   26705128
# 4  1385-12-26 2007-03-17  16.0  16.0  16.0      16.0   28239006789   14877283
#
#    count  yesterday  close  TEDPIX  year  month  quarter  day  weekday  \
# 0   7736       16.0   16.0     NaN  1385     12        4   20        1
# 1   9214       16.0   16.0     NaN  1385     12        4   21        2
# 2   5862       16.0   16.0     NaN  1385     12        4   22        3
# 3   1901       16.0   16.0     NaN  1385     12        4   23        4
# 4   1514       16.0   16.0     NaN  1385     12        4   26        0
#
#    shadow_up7d  shadow_low7d  body7d  shadow_up14d  shadow_low14d  body14d  \
# 0          NaN           NaN     NaN           NaN            NaN      NaN
# 1          NaN           NaN     NaN           NaN            NaN      NaN
# 2          NaN           NaN     NaN           NaN            NaN      NaN
# 3          NaN           NaN     NaN           NaN            NaN      NaN
# 4          0.0           0.0     0.0           NaN            NaN      NaN
#
#    shadow_up21d  shadow_low21d  body21d  shadow_up30d  shadow_low30d  body30d  \
# 0           NaN            NaN      NaN           NaN            NaN      NaN
# 1           NaN            NaN      NaN           NaN            NaN      NaN
# 2           NaN            NaN      NaN           NaN            NaN      NaN
# 3           NaN            NaN      NaN           NaN            NaN      NaN
# 4           NaN            NaN      NaN           NaN            NaN      NaN
#
#    shadow_up60d  shadow_low60d  body60d  shadow_up90d  shadow_low90d  body90d  \
# 0           NaN            NaN      NaN           NaN            NaN      NaN
# 1           NaN            NaN      NaN           NaN            NaN      NaN
# 2           NaN            NaN      NaN           NaN            NaN      NaN
# 3           NaN            NaN      NaN           NaN            NaN      NaN
# 4           NaN            NaN      NaN           NaN            NaN      NaN
#
#    max_price7d  min_price7d  ave_price7d  first_price7d  last_price7d  \
# 0          NaN          NaN          NaN            NaN           NaN
# 1          NaN          NaN          NaN            NaN           NaN
# 2          NaN          NaN          NaN            NaN           NaN
# 3          NaN          NaN          NaN            NaN           NaN
# 4         16.0         16.0          NaN           16.0          16.0
#
#    yesterday_price7d  max_price14d  min_price14d  first_price14d  \
# 0                NaN           NaN           NaN             NaN
# 1                NaN           NaN           NaN             NaN
# 2                NaN           NaN           NaN             NaN
# 3                NaN           NaN           NaN             NaN
# 4               16.0           NaN           NaN             NaN
#
#    last_price14d  yesterday_price14d  max_price21d  min_price21d  \
# 0            NaN                 NaN           NaN           NaN
# 1            NaN                 NaN           NaN           NaN
# 2            NaN                 NaN           NaN           NaN
# 3            NaN                 NaN           NaN           NaN
# 4            NaN                 NaN           NaN           NaN
#
#    first_price21d  last_price21d  yesterday_price21d  max_price30d  \
# 0             NaN            NaN                 NaN           NaN
# 1             NaN            NaN                 NaN           NaN
# 2             NaN            NaN                 NaN           NaN
# 3             NaN            NaN                 NaN           NaN
# 4             NaN            NaN                 NaN           NaN
#
#    min_price30d  first_price30d  last_price30d  yesterday_price30d  \
# 0           NaN             NaN            NaN                 NaN
# 1           NaN             NaN            NaN                 NaN
# 2           NaN             NaN            NaN                 NaN
# 3           NaN             NaN            NaN                 NaN
# 4           NaN             NaN            NaN                 NaN
#
#    max_price60d  min_price60d  first_price60d  last_price60d  \
# 0           NaN           NaN             NaN            NaN
# 1           NaN           NaN             NaN            NaN
# 2           NaN           NaN             NaN            NaN
# 3           NaN           NaN             NaN            NaN
# 4           NaN           NaN             NaN            NaN
#
#    yesterday_price60d  max_price90d  min_price90d  first_price90d  \
# 0                 NaN           NaN           NaN             NaN
# 1                 NaN           NaN           NaN             NaN
# 2                 NaN           NaN           NaN             NaN
# 3                 NaN           NaN           NaN             NaN
# 4                 NaN           NaN           NaN             NaN
#
#    last_price90d  yesterday_price90d  prp_high30d  prp_high60d  prp_high90d  \
# 0            NaN                 NaN          NaN          NaN          NaN
# 1            NaN                 NaN          NaN          NaN          NaN
# 2            NaN                 NaN          NaN          NaN          NaN
# 3            NaN                 NaN          NaN          NaN          NaN
# 4            NaN                 NaN          NaN          NaN          NaN
#
#    prp_low30d  prp_low60d  prp_low90d  prp_value3d30d  prp_value5d60d  \
# 0         NaN         NaN         NaN             NaN             NaN
# 1         NaN         NaN         NaN             NaN             NaN
# 2         NaN         NaN         NaN             NaN             NaN
# 3         NaN         NaN         NaN             NaN             NaN
# 4         NaN         NaN         NaN             NaN             NaN
#
#    ret1d_log  ret3d_log  ret7d_log  ret14d_log  ret30d_log  ret60d_log  \
# 0        0.0        NaN        NaN         NaN         NaN         NaN
# 1        0.0        NaN        NaN         NaN         NaN         NaN
# 2        0.0        0.0        NaN         NaN         NaN         NaN
# 3        0.0        0.0        NaN         NaN         NaN         NaN
# 4        0.0        0.0        NaN         NaN         NaN         NaN
#
#    lastclose_log  buy_queue_locked  sell_queue_locked  last1d_open  \
# 0            0.0                 0                  0          NaN
# 1            0.0                 0                  0         16.0
# 2            0.0                 0                  0         16.0
# 3            0.0                 0                  0         16.0
# 4            0.0                 0                  0         16.0
#
#    last1d_high  last1d_low  last1d_adjClose  last1d_value  last1d_volume  \
# 0          NaN         NaN              NaN           NaN            NaN
# 1         16.0        16.0             16.0  8.894372e+11    468077431.0
# 2         16.0        16.0             16.0  1.938795e+11    100041000.0
# 3         16.0        16.0             16.0  2.492415e+11    126270939.0
# 4         16.0        16.0             16.0  5.166638e+10     26705128.0
#
#    last1d_count  last1d_yesterday  last1d_close  last1d_TEDPIX         value  \
# 0           NaN               NaN           NaN            NaN  889437216900
# 1        7736.0              16.0          16.0            NaN  193879458000
# 2        9214.0              16.0          16.0            NaN  249241504527
# 3        5862.0              16.0          16.0            NaN   51666379451
# 4        1901.0              16.0          16.0            NaN   28239006789
#
#    value_20d  value_30d  value_40d  value_50d  value_60d  value_70d  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    value_80d  value_90d  value_100d  value_20d  value_30d  value_40d  \
# 0        NaN        NaN         NaN        NaN        NaN        NaN
# 1        NaN        NaN         NaN        NaN        NaN        NaN
# 2        NaN        NaN         NaN        NaN        NaN        NaN
# 3        NaN        NaN         NaN        NaN        NaN        NaN
# 4        NaN        NaN         NaN        NaN        NaN        NaN
#
#    value_50d  value_60d  value_70d  value_80d  value_90d  value_100d  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#    enter_individual_money  individual_buy_per_capita  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#    individual_sell_per_capita  individual_power  individual_power_3d  \
# 0                         NaN               NaN                  NaN
# 1                         NaN               NaN                  NaN
# 2                         NaN               NaN                  NaN
# 3                         NaN               NaN                  NaN
# 4                         NaN               NaN                  NaN
#
#    individual_power_5d  individual_power_10d  individual_power_20d  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
# 3                  NaN                   NaN                   NaN
# 4                  NaN                   NaN                   NaN
#
#    individual_power_prp_5d20
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
bbCols = BB(priceFeatures)
emaCols = EMA(foladHist)
macdCols = MACD(foladHist)
smaCols = SMA(foladHist)
stochasticCols = STOCHASTIC(foladHist)
rsiCols = RSI(foladHist)

indicatorFeatures = pd.concat(
    [
        bbCols,
        emaCols,
        macdCols,
        smaCols,
        stochasticCols,
        rsiCols,
    ], axis = 1
)

print(f'Shape of indicator features: {indicatorFeatures.shape}')
indicatorFeatures.head()
# Out:
# Shape of indicator features: (3503, 35)
#    BB_bbh  BB_bbl  last_BB_bbh  last_BB_bbl  BB_buy  BB_position  EMA_5d  \
# 0     NaN     NaN          NaN          NaN     NaN          NaN     NaN
# 1     NaN     NaN          NaN          NaN     NaN          NaN     NaN
# 2     NaN     NaN          NaN          NaN     NaN          NaN     NaN
# 3     NaN     NaN          NaN          NaN     NaN          NaN     NaN
# 4     NaN     NaN          NaN          NaN     NaN          NaN    16.0
#
#    last_EMA_5d  EMA_40d  last_EMA_40d  EMA_buy  EMA_position  MACD  MACD_diff  \
# 0          NaN      NaN           NaN      NaN           NaN   NaN        NaN
# 1          NaN      NaN           NaN      NaN           NaN   NaN        NaN
# 2          NaN      NaN           NaN      NaN           NaN   NaN        NaN
# 3          NaN      NaN           NaN      NaN           NaN   NaN        NaN
# 4          NaN      NaN           NaN      NaN           NaN   NaN        NaN
#
#    MACD_signal  MACD_buy  MACD_position  SMA10d  SMA20d  last_SMA20d  SMA30d  \
# 0          NaN       NaN            NaN     NaN     NaN          NaN     NaN
# 1          NaN       NaN            NaN     NaN     NaN          NaN     NaN
# 2          NaN       NaN            NaN     NaN     NaN          NaN     NaN
# 3          NaN       NaN            NaN     NaN     NaN          NaN     NaN
# 4          NaN       NaN            NaN     NaN     NaN          NaN     NaN
#
#    SMA50d  last_SMA50d  SMA80d  SMA_buy  SMA_position  STOCH_fast  STOCH_slow  \
# 0     NaN          NaN     NaN      NaN           NaN         NaN         NaN
# 1     NaN          NaN     NaN      NaN           NaN         NaN         NaN
# 2     NaN          NaN     NaN      NaN           NaN         NaN         NaN
# 3     NaN          NaN     NaN      NaN           NaN         NaN         NaN
# 4     NaN          NaN     NaN      NaN           NaN         NaN         NaN
#
#    last_STOCH_fast  last_STOCH_slow  STOCH_buy  STOCH_position  RSI  RSI_buy  \
# 0              NaN              NaN        NaN             NaN  NaN      NaN
# 1              NaN              NaN        NaN             NaN  NaN      NaN
# 2              NaN              NaN        NaN             NaN  NaN      NaN
# 3              NaN              NaN        NaN             NaN  NaN      NaN
# 4              NaN              NaN        NaN             NaN  NaN      NaN
#
#    RSI_position
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
features = pd.concat(
    [
        priceFeatures,
        indicatorFeatures
    ],
    axis = 1
)
print(f'shape of features after concatenation: {features.shape}')

features.dropna(
    axis = 'columns', 
    thresh = len(features) - 450,
    inplace = True
)
print(f'shape of features after drop non-essential columns: {features.shape}')
print(f'names of the columns that dropped: {(indicatorFeatures.columns.union(priceFeatures.columns)).difference(features.columns).to_list()}')

features.dropna(
    axis = 'index', 
    how = 'any',
    inplace = True
)
print(f'shape of features after drop non-essential rows: {features.shape}')
features.head()
# Out:
# shape of features after concatenation: (3503, 156)
# shape of features after drop non-essential columns: (3503, 150)
# names of the columns that dropped: ['BB_buy', 'EMA_buy', 'MACD_buy', 'RSI_buy', 'SMA_buy', 'STOCH_buy']
# shape of features after drop non-essential rows: (2974, 150)
#           jdate       date  open  high   low  adjClose         value  \
# 449  1388-02-15 2009-05-05  15.0  15.0  15.0      15.0    1081376640
# 450  1388-02-16 2009-05-06  15.0  15.0  15.0      15.0      91486200
# 471  1388-03-16 2009-06-06  17.0  17.0  17.0      17.0   92080076321
# 472  1388-03-17 2009-06-07  17.0  17.0  17.0      17.0  112619748590
# 473  1388-03-18 2009-06-08  17.0  18.0  17.0      17.0    9405809014
#
#        volume  count  yesterday  close  TEDPIX  year  month  quarter  day  \
# 449    586112     41       15.0   15.0  8699.5  1388      2        1   15
# 450     49452     11       15.0   15.0  8774.2  1388      2        1   16
# 471  45028304   1321       16.0   17.0  9121.3  1388      3        1   16
# 472  54450733    964       17.0   17.0  9195.1  1388      3        1   17
# 473   4426340    253       17.0   18.0  9235.5  1388      3        1   18
#
#      weekday  shadow_up7d  shadow_low7d    body7d  shadow_up14d  \
# 449        3          0.0     -0.066667  0.000000           0.0
# 450        4          0.0     -0.066667  0.000000           0.0
# 471        0          0.0      0.000000  0.133333           0.0
# 472        1          0.0      0.000000  0.066667           0.0
# 473        2          0.0      0.000000  0.125000           0.0
#
#      shadow_low14d   body14d  shadow_up21d  shadow_low21d  body21d  \
# 449      -0.066667  0.000000           0.0      -0.066667   0.0000
# 450      -0.066667  0.000000           0.0      -0.066667   0.0000
# 471      -0.062500  0.062500           0.0      -0.062500   0.0625
# 472      -0.062500  0.062500           0.0      -0.062500   0.0625
# 473      -0.066667  0.133333           0.0       0.000000   0.2000
#
#      shadow_up30d  shadow_low30d   body30d  shadow_up60d  shadow_low60d  \
# 449           0.0      -0.066667  0.000000           0.0      -0.066667
# 450           0.0      -0.066667  0.000000           0.0      -0.066667
# 471           0.0       0.000000  0.133333           0.0      -0.066667
# 472           0.0       0.000000  0.133333           0.0      -0.066667
# 473           0.0       0.000000  0.200000           0.0      -0.066667
#
#       body60d  shadow_up90d  shadow_low90d  body90d  max_price7d  min_price7d  \
# 449  0.000000        0.0625        -0.0625   0.0625         15.0         14.0
# 450  0.000000        0.0625        -0.0625   0.0625         15.0         14.0
# 471  0.133333        0.0000        -0.0625   0.1250         17.0         15.0
# 472  0.133333        0.0000        -0.0625   0.1250         17.0         16.0
# 473  0.200000        0.0000        -0.0625   0.1875         18.0         16.0
#
#      ave_price7d  first_price7d  last_price7d  yesterday_price7d  \
# 449    15.214286           15.0          15.0               15.0
# 450    15.200000           15.0          15.0               15.0
# 471    14.928571           15.0          17.0               15.0
# 472    14.957143           16.0          17.0               15.0
# 473    14.985714           16.0          18.0               16.0
#
#      max_price14d  min_price14d  first_price14d  last_price14d  \
# 449          15.0          14.0            15.0           15.0
# 450          15.0          14.0            15.0           15.0
# 471          17.0          15.0            16.0           17.0
# 472          17.0          15.0            16.0           17.0
# 473          18.0          15.0            16.0           18.0
#
#      yesterday_price14d  max_price21d  min_price21d  first_price21d  \
# 449                15.0          15.0          14.0            15.0
# 450                15.0          15.0          14.0            15.0
# 471                16.0          17.0          15.0            16.0
# 472                16.0          17.0          15.0            16.0
# 473                15.0          18.0          15.0            15.0
#
#      last_price21d  yesterday_price21d  max_price30d  min_price30d  \
# 449           15.0                15.0          15.0          14.0
# 450           15.0                15.0          15.0          14.0
# 471           17.0                16.0          17.0          15.0
# 472           17.0                16.0          17.0          15.0
# 473           18.0                15.0          18.0          15.0
#
#      first_price30d  last_price30d  yesterday_price30d  max_price60d  \
# 449            15.0           15.0                15.0          15.0
# 450            15.0           15.0                15.0          15.0
# 471            15.0           17.0                15.0          17.0
# 472            15.0           17.0                15.0          17.0
# 473            15.0           18.0                15.0          18.0
#
#      min_price60d  first_price60d  last_price60d  yesterday_price60d  \
# 449          14.0            15.0           15.0                15.0
# 450          14.0            15.0           15.0                15.0
# 471          14.0            15.0           17.0                15.0
# 472          14.0            15.0           17.0                15.0
# 473          14.0            15.0           18.0                15.0
#
#      max_price90d  min_price90d  first_price90d  last_price90d  \
# 449          17.0          14.0            16.0           15.0
# 450          17.0          14.0            16.0           15.0
# 471          17.0          14.0            15.0           17.0
# 472          17.0          14.0            15.0           17.0
# 473          18.0          14.0            15.0           18.0
#
#      yesterday_price90d  prp_high30d  prp_high60d  prp_high90d  prp_low30d  \
# 449                16.0     1.000000     0.882353     0.882353    1.071429
# 450                16.0     1.000000     0.882353     0.882353    1.071429
# 471                16.0     1.000000     1.000000     1.000000    1.214286
# 472                16.0     1.000000     1.000000     1.000000    1.214286
# 473                16.0     0.944444     0.944444     0.944444    1.214286
#
#      prp_low60d  prp_low90d  prp_value3d30d  prp_value5d60d  ret1d_log  \
# 449    1.071429    1.071429        1.041980        0.759095   0.000000
# 450    1.071429    1.071429        0.729210        0.722844   0.000000
# 471    1.214286    1.214286        3.307354        5.418591   0.060625
# 472    1.214286    1.214286        4.827436        6.531580   0.000000
# 473    1.214286    1.214286        4.550507        5.418452   0.000000
#
#      ret3d_log  ret7d_log  ret14d_log  ret30d_log  ret60d_log  lastclose_log  \
# 449   0.000000   0.000000    0.000000    0.000000   -0.125163       0.000000
# 450   0.000000   0.000000    0.000000    0.068993   -0.125163       0.000000
# 471   0.060625   0.125163    0.060625    0.125163    0.125163       0.000000
# 472   0.060625   0.125163    0.125163    0.125163    0.125163       0.000000
# 473   0.060625   0.125163    0.125163    0.125163    0.125163      -0.057158
#
#      buy_queue_locked  sell_queue_locked  last1d_open  last1d_high  \
# 449                 0                  0         14.0         15.0
# 450                 0                  0         15.0         15.0
# 471                 1                  0         16.0         16.0
# 472                 0                  0         17.0         17.0
# 473                 0                  0         17.0         17.0
#
#      last1d_low  last1d_adjClose  last1d_value  last1d_volume  last1d_count  \
# 449        14.0             15.0  3.759837e+09      2080737.0         204.0
# 450        15.0             15.0  1.081377e+09       586112.0          41.0
# 471        16.0             16.0  1.859993e+10      9365525.0         339.0
# 472        17.0             17.0  9.208008e+10     45028304.0        1321.0
# 473        17.0             17.0  1.126197e+11     54450733.0         964.0
#
#      last1d_yesterday  last1d_close  last1d_TEDPIX         value  \
# 449              15.0          15.0         8638.3    1081376640
# 450              15.0          15.0         8699.5      91486200
# 450    15.000000    15.000000          1.0  14.999977    14.999965  15.112079
# 471    16.379796    14.420204          1.0  16.156010    15.734016  15.405380
# 472    16.683216    14.316784          1.0  16.437340    16.156010  15.483167
# 473    16.926650    14.273350          1.0  16.624894    16.437340  15.557158
#
#      last_EMA_40d  EMA_position      MACD  MACD_diff  MACD_signal  \
# 449     15.123870           0.0  0.003671   0.011510    -0.007839
# 450     15.117827           0.0  0.004086   0.009540    -0.005454
# 471     15.323605           1.0  0.267554   0.128106     0.139448
# 472     15.405380           1.0  0.346968   0.166016     0.180952
# 473     15.483167           1.0  0.405233   0.179425     0.225808
#
#      MACD_position  SMA10d  SMA20d  last_SMA20d     SMA30d  SMA50d  \
# 449            1.0    15.0    15.0         15.0  14.833333   14.96
# 450            1.0    15.0    15.0         15.0  14.866667   14.94
# 471            0.0    15.6    15.5         15.4  15.333333   15.14
# 472            0.0    15.7    15.6         15.5  15.400000   15.20
# 473            0.0    15.9    15.7         15.6  15.466667   15.26
#
#      last_SMA50d   SMA80d  SMA_position  STOCH_fast  STOCH_slow  \
# 449        14.98  15.4625           0.0       100.0        80.0
# 450        14.96  15.4500           0.0       100.0        80.0
# 471        15.08  15.2250           0.0       100.0       100.0
# 472        15.14  15.2250           0.0       100.0       100.0
# 473        15.20  15.2250           0.0       100.0       100.0
#
#      last_STOCH_fast  last_STOCH_slow  STOCH_position        RSI  RSI_position
# 449            100.0             80.0             1.0  49.815169           1.0
# 450            100.0             80.0             1.0  49.815169           1.0
# 471            100.0             80.0             1.0  72.012437           0.0
# 472            100.0            100.0             1.0  72.012437           0.0
# 473            100.0            100.0             1.0  72.012437           0.0

# %%
# new
pivots = pd.DataFrame(
    peak_valley_pivots(
        foladHist['adjClose'].to_list(), 0.1
    ) ,
    columns = ['label']
) * -1

print(f'Number of each pivot {np.unique(pivots["label"], return_counts = True)}')

signals = pivots.replace(
    to_replace = 0, 
    value = np.nan
)
signals.fillna(
    method = 'ffill', 
    inplace = True
)
signals.fillna(
    method = 'bfill', 
    inplace = True
)

pivots.columns = ['pivots']
signals['date'] = foladHist['date']
pivots['date'] = foladHist['date']

print(f'Number of each class {np.unique(signals["label"], return_counts = True)}')
# Out:
# Number of each pivot (array([-1,  0,  1], dtype=int64), array([ 115, 3273,  115], dtype=int64))
# Number of each class (array([-1.,  1.]), array([1922, 1581], dtype=int64))

# %%
initFeatures = features.merge(
    signals,
    how = 'left',
    on = 'date'
)
initFeatures.to_csv(
    'initFeatures.csv', 
    index = False
)
print(f'Number of initial features: {initFeatures.shape}')
initFeatures
# Out:
# Number of initial features: (2974, 151)
#            jdate       date    open    high     low  adjClose          value  \
# 0     1388-02-15 2009-05-05    15.0    15.0    15.0      15.0     1081376640
# 1     1388-02-16 2009-05-06    15.0    15.0    15.0      15.0       91486200
# 2     1388-03-16 2009-06-06    17.0    17.0    17.0      17.0    92080076321
# 3     1388-03-17 2009-06-07    17.0    17.0    17.0      17.0   112619748590
# 4     1388-03-18 2009-06-08    17.0    18.0    17.0      17.0     9405809014
# ...          ...        ...     ...     ...     ...       ...            ...
# 2972          6000.0         6260.0              5840.0        6560.0
# 2973          6020.0         6210.0              5980.0        6560.0
#
#       min_price30d  first_price30d  last_price30d  yesterday_price30d  \
# 0             14.0            15.0           15.0                15.0
# 1             14.0            15.0           15.0                15.0
# 2             15.0            15.0           17.0                15.0
# 3             15.0            15.0           17.0                15.0
# 4             15.0            15.0           18.0                15.0
# ...            ...             ...            ...                 ...
# 2969        5320.0          5450.0         6380.0              5467.0
# 2970        5450.0          5470.0         6130.0              5390.0
# 2971        5450.0          5700.0         6240.0              5620.0
# 2972        5450.0          5630.0         6260.0              5630.0
# 2973        5450.0          5490.0         6210.0              5550.0
#
#       max_price60d  min_price60d  first_price60d  last_price60d  \
# 0             15.0          14.0            15.0           15.0
# 1             15.0          14.0            15.0           15.0
# 2             17.0          14.0            15.0           17.0
# 3             17.0          14.0            15.0           17.0
# 4             18.0          14.0            15.0           18.0
# ...            ...           ...             ...            ...
# 2969        6560.0        4706.0          5080.0         6380.0
# 2970        6560.0        4706.0          5030.0         6130.0
# 2971        6560.0        4706.0          5080.0         6240.0
# 2972        6560.0        4706.0          5040.0         6260.0
# 2973        6560.0        4706.0          4860.0         6210.0
#
#       yesterday_price60d  max_price90d  min_price90d  first_price90d  \
# 0                   15.0          17.0          14.0            16.0
# 1                   15.0          17.0          14.0            16.0
# 2                   15.0          17.0          14.0            15.0
# 3                   15.0          17.0          14.0            15.0
# 4                   15.0          18.0          14.0            15.0
# ...                  ...           ...           ...             ...
# 2969              5080.0        6560.0        4214.0          4914.0
# 2970              5030.0        6560.0        4214.0          4909.0
# 2971              5040.0        6560.0        4214.0          4921.0
# 2972              5060.0        6560.0        4214.0          5055.0
# 2973              4900.0        6560.0        4214.0          5070.0
#
#       last_price90d  yesterday_price90d  prp_high30d  prp_high60d  \
# 0              15.0                16.0     1.000000     0.882353
# 1              15.0                16.0     1.000000     0.882353
# 2              17.0                16.0     1.000000     1.000000
# 3              17.0                16.0     1.000000     1.000000
# 4              18.0                16.0     0.944444     0.944444
# ...             ...                 ...          ...          ...
# 2969         6380.0              4914.0     0.975610     0.975610
# 2970         6130.0              4909.0     0.935976     0.935976
# 2971         6240.0              4897.0     0.942073     0.942073
# 2972         6260.0              4979.0     0.949695     0.949695
# 2973         6210.0              5058.0     0.946646     0.946646
#
#       prp_high90d  prp_low30d  prp_low60d  prp_low90d  prp_value3d30d  \
# 0        0.882353    1.071429    1.071429    1.071429        1.041980
# 1        0.882353    1.071429    1.071429    1.071429        0.729210
# 2        1.000000    1.214286    1.214286    1.214286        3.307354
# 3        1.000000    1.214286    1.214286    1.214286        4.827436
# 4        0.944444    1.214286    1.214286    1.214286        4.550507
# ...           ...         ...         ...         ...             ...
# 2969     0.975610    1.359966    1.518747    1.518747        0.827425
# 2970     0.935976    1.304717    1.457048    1.457048        1.067730
# 2971     0.942073    1.313217    1.466540    1.466540        1.004205
# 2972     0.949695    1.309099    1.478405    1.478405        1.057584
# 2973     0.946646    1.293750    1.437833    1.473659        0.687979
#
#       prp_value5d60d  ret1d_log  ret3d_log  ret7d_log  ret14d_log  ret30d_log  \
# %%
X_train, X_test, y_train, y_test = train_test_split(
    initFeatures.iloc[:, 2:-1].values, 
    initFeatures.iloc[:, -1].values, 
    shuffle = False, 
    random_state = 0
)

# %% [markdown]
# Hyperparameters are selected by the Bayesian optimization method. <a href = 'https://www.kaggle.com/alirezahanifi/iran-stock-market-bayesian-optimization-part'>Link</a> to the notebook of this part of the code in Kaggle.

# %%
trainPred, testPred, trainProb, testProb, featureImport, trainClassReport,\
    testClassReport = RFClf(X_train, y_train, X_test, y_test)

print(f'Training classification report:\n{trainClassReport}')
print(f'Testing classification report:\n{testClassReport}')
# Out:
# Training classification report:
#               precision    recall  f1-score   support
#
#         -1.0       0.86      0.80      0.83      1246
#          1.0       0.77      0.84      0.80       984
#
#     accuracy                           0.82      2230
#    macro avg       0.82      0.82      0.82      2230
# weighted avg       0.82      0.82      0.82      2230
#
# Testing classification report:
#               precision    recall  f1-score   support
#
#         -1.0       0.78      0.78      0.78       496
#          1.0       0.56      0.57      0.57       248
#
#     accuracy                           0.71       744
#    macro avg       0.67      0.67      0.67       744
# weighted avg       0.71      0.71      0.71       744

# %%
# output for API 

output = pd.DataFrame()
output['jdate'] = initFeatures['jdate']
labelProb = np.concatenate((trainProb, testProb), axis = 0)[:,1]
output['labelProb'] = labelProb
output.to_csv('../api/output_for_API.csv', index = False)

# %%
importance = pd.DataFrame(
    {
        'Features': initFeatures.iloc[:, 2:-1].columns,
        'Scores': featureImport
    }
).sort_values(by = ['Scores'])

plt.figure(figsize = (10, 30))
plt.tight_layout()

plt.barh(
    y = importance['Features'],
    width = importance['Scores'],
    height = 0.9,
    color = plt.cm.get_cmap('RdYlGn')(importance['Scores'] / max(importance['Scores']))
)
plt.margins(y=0)

# %%
def convertLabel(df, colName):
    name = str(colName + '01')
    df.loc[initFeatures[colName] == -1, name] = 0
    df[name] = df[name].fillna(1)
    return df
    
initFeatures['priChange'] = initFeatures['adjClose'] - initFeatures['yesterday']
labelPred = np.concatenate((trainPred, testPred), axis = 0)
initFeatures['labelPred'] = labelPred
labelProb = np.concatenate((trainProb, testProb), axis = 0)[:,1]
initFeatures['labelProb'] = labelProb

initFeatures = convertLabel(initFeatures, 'label')
initFeatures = convertLabel(initFeatures, 'labelPred')

initFeatures = initFeatures.merge(
    pivots,
    how = 'left',
    on = 'date'
)

initFeatures.head()
# Out:
#         jdate       date  open  high   low  adjClose         value    volume  \
# 0  1388-02-15 2009-05-05  15.0  15.0  15.0      15.0    1081376640    586112
# 1  1388-02-16 2009-05-06  15.0  15.0  15.0      15.0      91486200     49452
# 2  1388-03-16 2009-06-06  17.0  17.0  17.0      17.0   92080076321  45028304
# 3  1388-03-17 2009-06-07  17.0  17.0  17.0      17.0  112619748590  54450733
# 4  1388-03-18 2009-06-08  17.0  18.0  17.0      17.0    9405809014   4426340
#
#    count  yesterday  close  TEDPIX  year  month  quarter  day  weekday  \
# 0     41       15.0   15.0  8699.5  1388      2        1   15        3
# 1     11       15.0   15.0  8774.2  1388      2        1   16        4
# 2   1321       16.0   17.0  9121.3  1388      3        1   16        0
# 3    964       17.0   17.0  9195.1  1388      3        1   17        1
# 4    253       17.0   18.0  9235.5  1388      3        1   18        2
#
#    shadow_up7d  shadow_low7d    body7d  shadow_up14d  shadow_low14d   body14d  \
# 0          0.0     -0.066667  0.000000           0.0      -0.066667  0.000000
# 1          0.0     -0.066667  0.000000           0.0      -0.066667  0.000000
# 2          0.0      0.000000  0.133333           0.0      -0.062500  0.062500
# 3          0.0      0.000000  0.066667           0.0      -0.062500  0.062500
# 4          0.0      0.000000  0.125000           0.0      -0.066667  0.133333
#
#    shadow_up21d  shadow_low21d  body21d  shadow_up30d  shadow_low30d  \
# 0           0.0      -0.066667   0.0000           0.0      -0.066667
# 1           0.0      -0.066667   0.0000           0.0      -0.066667
# 2           0.0      -0.062500   0.0625           0.0       0.000000
# 3           0.0      -0.062500   0.0625           0.0       0.000000
# 4           0.0       0.000000   0.2000           0.0       0.000000
#
#     body30d  shadow_up60d  shadow_low60d   body60d  shadow_up90d  \
# 0  0.000000           0.0      -0.066667  0.000000        0.0625
# 1  0.000000           0.0      -0.066667  0.000000        0.0625
# 2  0.133333           0.0      -0.066667  0.133333        0.0000
# 3  0.133333           0.0      -0.066667  0.133333        0.0000
# 4  0.200000           0.0      -0.066667  0.200000        0.0000
#
#    shadow_low90d  body90d  max_price7d  min_price7d  ave_price7d  \
# 0        -0.0625   0.0625         15.0         14.0    15.214286
# 1        -0.0625   0.0625         15.0         14.0    15.200000
# 2        -0.0625   0.1250         17.0         15.0    14.928571
# 3        -0.0625   0.1250         17.0         16.0    14.957143
# 4        -0.0625   0.1875         18.0         16.0    14.985714
#
#    first_price7d  last_price7d  yesterday_price7d  max_price14d  min_price14d  \
# 0           15.0          15.0               15.0          15.0          14.0
# 1           15.0          15.0               15.0          15.0          14.0
# 2           15.0          17.0               15.0          17.0          15.0
# 3           16.0          17.0               15.0          17.0          15.0
# 4           16.0          18.0               16.0          18.0          15.0
#
#    first_price14d  last_price14d  yesterday_price14d  max_price21d  \
# 0            15.0           15.0                15.0          15.0
# 1            15.0           15.0                15.0          15.0
# 2            16.0           17.0                16.0          17.0
# 3            16.0           17.0                16.0          17.0
# 4            16.0           18.0                15.0          18.0
#
#    min_price21d  first_price21d  last_price21d  yesterday_price21d  \
# 0          14.0            15.0           15.0                15.0
# 1          14.0            15.0           15.0                15.0
# 2          15.0            16.0           17.0                16.0
# 3          15.0            16.0           17.0                16.0
# 4          15.0            15.0           18.0                15.0
#
#    max_price30d  min_price30d  first_price30d  last_price30d  \
# 0          15.0          14.0            15.0           15.0
# 1          15.0          14.0            15.0           15.0
# 2          17.0          15.0            15.0           17.0
# 3          17.0          15.0            15.0           17.0
# 4          18.0          15.0            15.0           18.0
#
#    yesterday_price30d  max_price60d  min_price60d  first_price60d  \
# 0                15.0          15.0          14.0            15.0
# 1                15.0          15.0          14.0            15.0
# 2                15.0          17.0          14.0            15.0
# 3                15.0          17.0          14.0            15.0
# 4                15.0          18.0          14.0            15.0
#
#    last_price60d  yesterday_price60d  max_price90d  min_price90d  \
# 0           15.0                15.0          17.0          14.0
# 1           15.0                15.0          17.0          14.0
# 2           17.0                15.0          17.0          14.0
# 3           17.0                15.0          17.0          14.0
# 4           18.0                15.0          18.0          14.0
#
#    first_price90d  last_price90d  yesterday_price90d  prp_high30d  \
# 0            16.0           15.0                16.0     1.000000
# 1            16.0           15.0                16.0     1.000000
# 2            15.0           17.0                16.0     1.000000
# 3            15.0           17.0                16.0     1.000000
# 4            15.0           18.0                16.0     0.944444
#
#    prp_high60d  prp_high90d  prp_low30d  prp_low60d  prp_low90d  \
# 0     0.882353     0.882353    1.071429    1.071429    1.071429
# 1     0.882353     0.882353    1.071429    1.071429    1.071429
# 2     1.000000     1.000000    1.214286    1.214286    1.214286
# 3     1.000000     1.000000    1.214286    1.214286    1.214286
# 4     0.944444     0.944444    1.214286    1.214286    1.214286
#
#    prp_value3d30d  prp_value5d60d  ret1d_log  ret3d_log  ret7d_log  \
# 0        1.041980        0.759095   0.000000   0.000000   0.000000
# 1        0.729210        0.722844   0.000000   0.000000   0.000000
# 2        3.307354        5.418591   0.060625   0.060625   0.125163
# 3        4.827436        6.531580   0.000000   0.060625   0.125163
# 4        4.550507        5.418452   0.000000   0.060625   0.125163
#
#    ret14d_log  ret30d_log  ret60d_log  lastclose_log  buy_queue_locked  \
# 0    0.000000    0.000000   -0.125163       0.000000                 0
# 1    0.000000    0.068993   -0.125163       0.000000                 0
# 2    0.060625    0.125163    0.125163       0.000000                 1
# 3    0.125163    0.125163    0.125163       0.000000                 0
# 4    0.125163    0.125163    0.125163      -0.057158                 0
#
#    sell_queue_locked  last1d_open  last1d_high  last1d_low  last1d_adjClose  \
# 0                  0         14.0         15.0        14.0             15.0
# 1                  0         15.0         15.0        15.0             15.0
# 2                  0         16.0         16.0        16.0             16.0
# 3                  0         17.0         17.0        17.0             17.0
# 4                  0         17.0         17.0        17.0             17.0
#
#    last1d_value  last1d_volume  last1d_count  last1d_yesterday  last1d_close  \
# 0  3.759837e+09      2080737.0         204.0              15.0          15.0
# 1  1.081377e+09       586112.0          41.0              15.0          15.0
# 2  1.859993e+10      9365525.0         339.0              16.0          16.0
# 3  9.208008e+10     45028304.0        1321.0              16.0          17.0
# 4  1.126197e+11     54450733.0         964.0              17.0          17.0
#
#    last1d_TEDPIX         value     value_20d     value_30d     value_40d  \
# 0         8638.3    1081376640  3.059118e+09  2.310900e+09  2.418149e+09
# 1         8699.5      91486200  3.039489e+09  2.254816e+09  2.418696e+09
# 2         9081.7   92080076321  1.641150e+10  1.172531e+10  9.727657e+09
# 3         9121.3  112619748590  2.202994e+10  1.541880e+10  1.250131e+10
# 4         9195.1    9405809014  2.224937e+10  1.568365e+10  1.261688e+10
#
#       value_50d     value_60d     value_70d     value_80d     value_90d  \
# 0  2.313320e+09  2.470778e+09  3.837590e+09  3.865225e+09  4.283519e+09
# 1  2.299024e+09  2.338820e+09  3.783634e+09  3.790551e+09  4.222707e+09
# 2  7.911744e+09  6.978656e+09  6.279276e+09  5.801021e+09  6.573516e+09
# 3  1.015986e+10  8.750614e+09  7.874650e+09  7.158715e+09  7.807720e+09
# 4  1.033730e+10  8.798262e+09  8.002837e+09  7.261599e+09  7.903900e+09
#
# 1         15.0  14.866667   14.94        14.96  15.4500           0.0
# 2         15.4  15.333333   15.14        15.08  15.2250           0.0
# 3         15.5  15.400000   15.20        15.14  15.2250           0.0
# 4         15.6  15.466667   15.26        15.20  15.2250           0.0
#
#    STOCH_fast  STOCH_slow  last_STOCH_fast  last_STOCH_slow  STOCH_position  \
# 0       100.0        80.0            100.0             80.0             1.0
# 1       100.0        80.0            100.0             80.0             1.0
# 2       100.0       100.0            100.0             80.0             1.0
# 3       100.0       100.0            100.0            100.0             1.0
# 4       100.0       100.0            100.0            100.0             1.0
#
#          RSI  RSI_position  label  priChange  labelPred  labelProb  label01  \
# 0  49.815169           1.0    1.0        0.0        1.0   0.814041      1.0
# 1  49.815169           1.0    1.0        0.0        1.0   0.831511      1.0
# 2  72.012437           0.0   -1.0        1.0        1.0   0.711333      0.0
# 3  72.012437           0.0    1.0        0.0        1.0   0.748854      1.0
# 4  72.012437           0.0    1.0        0.0        1.0   0.740568      1.0
#
#    labelPred01  pivots
# 0          1.0       0
# 1          1.0       0
# 2          1.0      -1
# 3          1.0       1
# 4          1.0       0

# %%
def plotLabel(df, trainPred, testPred):
    
    date = df['date']
    price = df['adjClose']
    label = df['label']
    neutralIndex = df['pivots'] == 0
    trainBuy = df.loc[df.index < len(trainPred)].loc[trainPred == 1].index 
    trainSell = df.loc[df.index < len(trainPred)].loc[trainPred == -1].index
    trainTestBorder = df.loc[df.index == len(trainPred)].index
    testBuy = df.loc[df.index >= len(trainPred)].loc[testPred == 1].index 
    testSell = df.loc[df.index >= len(trainPred)].loc[testPred == -1].index 
    
    plt.figure(figsize = (30, 15))
    plt.title('Price of Mobarakeh Steel Company', fontsize = 15)
    plt.plot(
        date,
        price,
        color = 'blue',
        lw = 3,
        label = 'Price'
    )    
    plt.plot(
        date.iloc[np.where(~neutralIndex)], 
        price.iloc[np.where(~neutralIndex)],
        color = 'black',
        lw = 2,
        label = 'ZigZag'
    )


    # train
    plt.scatter(
        date.iloc[trainSell] , 
        price.iloc[trainSell],
        color = 'red',
        s = 30,
        label = 'Sell Position based on RF (on train dataset)'
    )
    plt.scatter(
        date.iloc[trainBuy], 
        price.iloc[trainBuy],
        color = 'green',
        s = 30,
        label = 'Buy Position based on RF (on train dataset)'
    )
    plt.yscale('log')

    plt.axvline(date.iloc[trainTestBorder], color = 'purple', label = 'Train-Test Border')

    # test
    plt.scatter(
        date.iloc[testSell] , 
        price.iloc[testSell],
        color = 'red',
        s = 30,
        label = 'Sell Position based on RF (on test dataset)'
    )
    plt.scatter(
        date.iloc[testBuy], 
        price.iloc[testBuy],
        color = 'green',
        s = 30,
        label = 'Buy Position based on RF (on test dataset)'
    )
    plt.yscale('log')
    plt.legend()

print(f'Return in passive invesitng in train section: {(initFeatures["adjClose"].iloc[len(trainPred) - 1]  / initFeatures["adjClose"].iloc[0]):0.0%}')
print(f'Return in passive invesitng in test section: {(initFeatures["adjClose"].iloc[-1]  / initFeatures["adjClose"].iloc[len(trainPred)]):0.0%}')

print(f'Max return in train section based on zigzag: {((initFeatures["priChange"] * initFeatures["label01"].shift(2)).iloc[:len(trainPred)].sum() / initFeatures["adjClose"].iloc[0]):0.0%}')
print(f'Max return in test section based on zigzag: {((initFeatures["priChange"] * initFeatures["label01"].shift(2)).iloc[len(trainPred):].sum() / initFeatures["adjClose"].iloc[len(trainPred)]):0.0%}')

print(f'Return in train section based on prediction: {((initFeatures["priChange"] * initFeatures["labelPred01"].shift(2)).iloc[:len(trainPred)].sum() / initFeatures["adjClose"].iloc[0]):0.0%}')
print(f'Return in test section based on prediction: {((initFeatures["priChange"] * initFeatures["labelPred01"].shift(2)).iloc[len(trainPred):].sum() / initFeatures["adjClose"].iloc[len(trainPred)]):0.0%}')
plotLabel(initFeatures, trainPred, testPred)
# Out:
# Return in passive invesitng in train section: 5960%
# Return in passive invesitng in test section: 694%
# Max return in train section based on zigzag: 10367%
# Max return in test section based on zigzag: 1981%
# Return in train section based on prediction: 6540%
# Return in test section based on prediction: 417%

# %% [markdown]
# # Bayesian Optimization

# %%
# def rfcScore(
#     n_estimators,
#     min_samples_split,
#     min_samples_leaf,
#     max_depth):
    
#     n_estimators = int(n_estimators)
#     min_samples_split = int(min_samples_split)
#     min_samples_leaf = int(min_samples_leaf)
#     max_depth = int(max_depth)
    
#     params = {
#         'n_estimators': n_estimators,
#         'criterion': 'entropy',
#         'min_samples_split': min_samples_split,
#         'min_samples_leaf': min_samples_leaf,
#         'max_depth': max_depth,
#         'max_features': 'sqrt',
#         'n_jobs': -1,
#         'random_state': 1,
#         'class_weight': 'balanced_subsample'
#     }

#     rfc = RandomForestClassifier(
#         **params
#     )

#     score = cross_val_score(
#         rfc, 
#         X = X_train,
#         y = y_train,
#         scoring = 'f1_weighted'
#     ).mean()

#     return score

# def RFClf(train_data, train_label, test_data, test_label, params):
    
#     clf = RandomForestClassifier(
#         n_estimators = int(params['n_estimators']),
#         max_depth = int(params['max_depth']),
#         min_samples_leaf = int(params['min_samples_leaf']),
#         min_samples_split = int(params['min_samples_split']),
#         criterion = 'entropy',
#         class_weight = 'balanced_subsample',
#         random_state = 0
#     )

#     clf.fit(train_data, train_label)
    
#     trainPred = clf.predict(train_data)
#     testPred = clf.predict(test_data)

#     trainProb = clf.predict_proba(train_data)
#     testProb = clf.predict_proba(test_data)

#     featureImport = clf.feature_importances_

#     trainClassReport = metrics.classification_report(train_label, trainPred)
#     testClassReport = metrics.classification_report(test_label, testPred)

#     return trainPred, testPred, trainProb, testProb, featureImport, trainClassReport, testClassReport

# rfcBound = {
#     'n_estimators': (100, 200),
#     'min_samples_split': (2, 5),
#     'min_samples_leaf': (1, 5),
#     'max_depth': (4, 8)
# }
# optimizer = BayesianOptimization(
#     f = rfcScore, 
#     pbounds = rfcBound,
#     random_state = 1
# )
# optimizer.maximize(
#     init_points = 3,
#     n_iter = 5,
# )

# print(f"Selected parameters: {optimizer.max['params']}\n")

# trainPred, testPred, trainProb, testProb, featureImport, trainClassReport, testClassReport = RFClf(X_train, y_train, X_test, y_test, optimizer.max['params'])

# print(f'Training classification report:\n{trainClassReport}')
# print(f'Testing classification report:\n{testClassReport}')
